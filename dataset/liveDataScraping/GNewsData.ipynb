# %%
import os
import sys
import time
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
# ── CONFIGURATION ─────────────────────────────────────────────────────────────
API_KEY              = "3170106d1a0e96162d6bd13e1921de31"

OUTPUT_CSV   = 'gnews_articles.csv'
INTERVALS    = 52           # one per week
DESIRED_PER  = 20           # target per interval
PER_PAGE_MAX = 10           # free tier limit
PAGES_PER    = (DESIRED_PER + PER_PAGE_MAX - 1) // PER_PAGE_MAX  # = 2

def save_results(articles, filename=OUTPUT_CSV):
    df = pd.DataFrame(articles)
    df.to_csv(filename, index=False)
    print(f"[{datetime.utcnow():%Y-%m-%d %H:%M:%S}] Saved {len(df)} articles")

def fetch_uniform_articles():
    end_dt   = datetime.utcnow()
    start_dt = end_dt - timedelta(days=365)
    # split into 53 timestamps → 52 weekly spans
    splits = pd.date_range(start=start_dt, end=end_dt, periods=INTERVALS+1).to_pydatetime()
    all_articles = []

    for i in range(INTERVALS):
        frm = splits[i].strftime('%Y-%m-%dT%H:%M:%SZ')
        to  = splits[i+1].strftime('%Y-%m-%dT%H:%M:%SZ')

        fetched_this_interval = 0
        for page in range(1, PAGES_PER+1):
            params = {
                'q':       'news',       # all topics
                'from':    frm,
                'to':      to,
                'lang':    'en',
                'country': 'us',
                'max':     PER_PAGE_MAX,
                'page':    page,
                'token':   API_KEY
            }
            try:
                r = requests.get('https://gnews.io/api/v4/search', params=params, timeout=10)
                r.raise_for_status()
                batch = r.json().get('articles', [])
                for art in batch:
                    all_articles.append({
                        'title':       art.get('title'),
                        'description': art.get('description'),
                        'url':         art.get('url'),
                        'publishedAt': art.get('publishedAt'),
                        'source_name': art.get('source', {}).get('name')
                    })
                fetched_this_interval += len(batch)
                print(f"✅ Week {i+1}/{INTERVALS}, page {page}: {len(batch)} articles")
            except Exception as e:
                print(f"⚠️  Week {i+1}, page {page} failed: {e}", file=sys.stderr)
            time.sleep(1)  # throttle between requests

        print(f"— Week {i+1} total: {fetched_this_interval} articles")
        save_results(all_articles)

    return all_articles

if __name__ == '__main__':
    fetch_uniform_articles()
# Out:
# ✅ Week 1/52, page 1: 10 articles
# ✅ Week 1/52, page 2: 10 articles
# — Week 1 total: 20 articles
# [2025-04-20 15:34:51] Saved 20 articles
# ✅ Week 2/52, page 1: 10 articles
# ✅ Week 2/52, page 2: 10 articles
# — Week 2 total: 20 articles
# [2025-04-20 15:34:54] Saved 40 articles
# ✅ Week 3/52, page 1: 10 articles
# ✅ Week 3/52, page 2: 10 articles
# — Week 3 total: 20 articles
# [2025-04-20 15:34:57] Saved 60 articles
# ✅ Week 4/52, page 1: 10 articles
# ✅ Week 4/52, page 2: 10 articles
# — Week 4 total: 20 articles
# [2025-04-20 15:35:01] Saved 80 articles
# ✅ Week 5/52, page 1: 10 articles
# ✅ Week 5/52, page 2: 10 articles
# — Week 5 total: 20 articles
# [2025-04-20 15:35:04] Saved 100 articles
# ✅ Week 6/52, page 1: 10 articles
# ✅ Week 6/52, page 2: 10 articles
# — Week 6 total: 20 articles
# [2025-04-20 15:35:07] Saved 120 articles
# ✅ Week 7/52, page 1: 10 articles
# ✅ Week 7/52, page 2: 10 articles
# — Week 7 total: 20 articles
# [2025-04-20 15:35:10] Saved 140 articles
# ✅ Week 8/52, page 1: 10 articles
# ✅ Week 8/52, page 2: 10 articles
# — Week 8 total: 20 articles
# [2025-04-20 15:35:14] Saved 160 articles
# ✅ Week 9/52, page 1: 10 articles
# ✅ Week 9/52, page 2: 10 articles
# — Week 9 total: 20 articles
# [2025-04-20 15:35:17] Saved 180 articles
# ✅ Week 10/52, page 1: 10 articles
# ✅ Week 10/52, page 2: 10 articles
# — Week 10 total: 20 articles
# [2025-04-20 15:35:20] Saved 200 articles
# ✅ Week 11/52, page 1: 10 articles
# ✅ Week 11/52, page 2: 10 articles
# — Week 11 total: 20 articles
# [2025-04-20 15:35:23] Saved 220 articles
# ✅ Week 12/52, page 1: 10 articles
# ✅ Week 12/52, page 2: 10 articles
# — Week 12 total: 20 articles
# [2025-04-20 15:35:27] Saved 240 articles
# ✅ Week 13/52, page 1: 10 articles
# ✅ Week 13/52, page 2: 10 articles
# — Week 13 total: 20 articles
# [2025-04-20 15:35:30] Saved 260 articles
# ✅ Week 14/52, page 1: 10 articles
# ✅ Week 14/52, page 2: 10 articles
# — Week 14 total: 20 articles
# [2025-04-20 15:35:33] Saved 280 articles
# ✅ Week 15/52, page 1: 10 articles
# ✅ Week 15/52, page 2: 10 articles
# — Week 15 total: 20 articles
# [2025-04-20 15:35:36] Saved 300 articles
# ✅ Week 16/52, page 1: 10 articles
# ✅ Week 16/52, page 2: 10 articles
# — Week 16 total: 20 articles
# [2025-04-20 15:35:40] Saved 320 articles
# ✅ Week 17/52, page 1: 10 articles
# ✅ Week 17/52, page 2: 10 articles
# — Week 17 total: 20 articles
# [2025-04-20 15:35:43] Saved 340 articles
# ✅ Week 18/52, page 1: 10 articles
# ✅ Week 18/52, page 2: 10 articles
# — Week 18 total: 20 articles
# [2025-04-20 15:35:46] Saved 360 articles
# ✅ Week 19/52, page 1: 10 articles
# ✅ Week 19/52, page 2: 10 articles
# — Week 19 total: 20 articles
# [2025-04-20 15:35:49] Saved 380 articles
# ✅ Week 20/52, page 1: 10 articles
# ✅ Week 20/52, page 2: 10 articles
# — Week 20 total: 20 articles
# [2025-04-20 15:35:53] Saved 400 articles
# ✅ Week 21/52, page 1: 10 articles
# ✅ Week 21/52, page 2: 10 articles
# — Week 21 total: 20 articles
# [2025-04-20 15:35:56] Saved 420 articles
# ✅ Week 22/52, page 1: 10 articles
# ✅ Week 22/52, page 2: 10 articles
# — Week 22 total: 20 articles
# [2025-04-20 15:35:59] Saved 440 articles
# ✅ Week 23/52, page 1: 10 articles
# ✅ Week 23/52, page 2: 10 articles
# — Week 23 total: 20 articles
# [2025-04-20 15:36:02] Saved 460 articles
# ✅ Week 24/52, page 1: 10 articles
# ✅ Week 24/52, page 2: 10 articles
# — Week 24 total: 20 articles
# [2025-04-20 15:36:06] Saved 480 articles
# ✅ Week 25/52, page 1: 10 articles
# ✅ Week 25/52, page 2: 10 articles
# — Week 25 total: 20 articles
# [2025-04-20 15:36:09] Saved 500 articles
# ✅ Week 26/52, page 1: 10 articles
# ✅ Week 26/52, page 2: 10 articles
# — Week 26 total: 20 articles
# [2025-04-20 15:36:12] Saved 520 articles
# ✅ Week 27/52, page 1: 10 articles
# ✅ Week 27/52, page 2: 10 articles
# — Week 27 total: 20 articles
# [2025-04-20 15:36:15] Saved 540 articles
# ✅ Week 28/52, page 1: 10 articles
# ✅ Week 28/52, page 2: 10 articles
# — Week 28 total: 20 articles
# [2025-04-20 15:36:19] Saved 560 articles
# ✅ Week 29/52, page 1: 10 articles
# ✅ Week 29/52, page 2: 10 articles
# — Week 29 total: 20 articles
# [2025-04-20 15:36:22] Saved 580 articles
# ✅ Week 30/52, page 1: 10 articles
# ✅ Week 30/52, page 2: 10 articles
# — Week 30 total: 20 articles
# [2025-04-20 15:36:25] Saved 600 articles
# ✅ Week 31/52, page 1: 10 articles
# ✅ Week 31/52, page 2: 10 articles
# — Week 31 total: 20 articles
# [2025-04-20 15:36:28] Saved 620 articles
# ✅ Week 32/52, page 1: 10 articles
# ✅ Week 32/52, page 2: 10 articles
# — Week 32 total: 20 articles
# [2025-04-20 15:36:32] Saved 640 articles
# ✅ Week 33/52, page 1: 10 articles
# ✅ Week 33/52, page 2: 10 articles
# — Week 33 total: 20 articles
# [2025-04-20 15:36:35] Saved 660 articles
# ✅ Week 34/52, page 1: 10 articles
# ✅ Week 34/52, page 2: 10 articles
# — Week 34 total: 20 articles
# [2025-04-20 15:36:38] Saved 680 articles
# ✅ Week 35/52, page 1: 10 articles
# ✅ Week 35/52, page 2: 10 articles
# — Week 35 total: 20 articles
# [2025-04-20 15:36:41] Saved 700 articles
# ✅ Week 36/52, page 1: 10 articles
# ✅ Week 36/52, page 2: 10 articles
# — Week 36 total: 20 articles
# [2025-04-20 15:36:45] Saved 720 articles
# ✅ Week 37/52, page 1: 10 articles
# ✅ Week 37/52, page 2: 10 articles
# — Week 37 total: 20 articles
# [2025-04-20 15:36:48] Saved 740 articles
# ✅ Week 38/52, page 1: 10 articles
# ✅ Week 38/52, page 2: 10 articles
# — Week 38 total: 20 articles
# [2025-04-20 15:36:51] Saved 760 articles
# ✅ Week 39/52, page 1: 10 articles
# ✅ Week 39/52, page 2: 10 articles
# — Week 39 total: 20 articles
# [2025-04-20 15:36:54] Saved 780 articles
# ✅ Week 40/52, page 1: 10 articles
# ✅ Week 40/52, page 2: 10 articles
# — Week 40 total: 20 articles
# [2025-04-20 15:36:58] Saved 800 articles
# ✅ Week 41/52, page 1: 10 articles
# ✅ Week 41/52, page 2: 10 articles
# — Week 41 total: 20 articles
# [2025-04-20 15:37:01] Saved 820 articles
# ✅ Week 42/52, page 1: 10 articles
# ✅ Week 42/52, page 2: 10 articles
# — Week 42 total: 20 articles
# [2025-04-20 15:37:04] Saved 840 articles
# ✅ Week 43/52, page 1: 10 articles
# ✅ Week 43/52, page 2: 10 articles
# — Week 43 total: 20 articles
# [2025-04-20 15:37:07] Saved 860 articles
# ✅ Week 44/52, page 1: 10 articles
# ✅ Week 44/52, page 2: 10 articles
# — Week 44 total: 20 articles
# [2025-04-20 15:37:11] Saved 880 articles
# ✅ Week 45/52, page 1: 10 articles
# ✅ Week 45/52, page 2: 10 articles
# — Week 45 total: 20 articles
# [2025-04-20 15:37:14] Saved 900 articles
# ✅ Week 46/52, page 1: 10 articles
# ✅ Week 46/52, page 2: 10 articles
# — Week 46 total: 20 articles
# [2025-04-20 15:37:17] Saved 920 articles
# ✅ Week 47/52, page 1: 10 articles
# ✅ Week 47/52, page 2: 10 articles
# — Week 47 total: 20 articles
# [2025-04-20 15:37:20] Saved 940 articles
# ✅ Week 48/52, page 1: 10 articles
# ✅ Week 48/52, page 2: 10 articles
# — Week 48 total: 20 articles
# [2025-04-20 15:37:24] Saved 960 articles
# ✅ Week 49/52, page 1: 10 articles
# ✅ Week 49/52, page 2: 10 articles
# — Week 49 total: 20 articles
# [2025-04-20 15:37:27] Saved 980 articles
# ✅ Week 50/52, page 1: 10 articles
# ✅ Week 50/52, page 2: 10 articles
# — Week 50 total: 20 articles
# [2025-04-20 15:37:30] Saved 1000 articles
# ⚠️  Week 51, page 1 failed: 403 Client Error: Forbidden for url: https://gnews.io/api/v4/search?q=news&from=2025-04-06T14%3A39%3A25Z&to=2025-04-13T15%3A07%3A06Z&lang=en&country=us&max=10&page=1&token=3170106d1a0e96162d6bd13e1921de31
# ⚠️  Week 51, page 2 failed: 403 Client Error: Forbidden for url: https://gnews.io/api/v4/search?q=news&from=2025-04-06T14%3A39%3A25Z&to=2025-04-13T15%3A07%3A06Z&lang=en&country=us&max=10&page=2&token=3170106d1a0e96162d6bd13e1921de31
# — Week 51 total: 0 articles
# [2025-04-20 15:37:33] Saved 1000 articles
# ⚠️  Week 52, page 1 failed: 403 Client Error: Forbidden for url: https://gnews.io/api/v4/search?q=news&from=2025-04-13T15%3A07%3A06Z&to=2025-04-20T15%3A34%3A48Z&lang=en&country=us&max=10&page=1&token=3170106d1a0e96162d6bd13e1921de31
# ⚠️  Week 52, page 2 failed: 403 Client Error: Forbidden for url: https://gnews.io/api/v4/search?q=news&from=2025-04-13T15%3A07%3A06Z&to=2025-04-20T15%3A34%3A48Z&lang=en&country=us&max=10&page=2&token=3170106d1a0e96162d6bd13e1921de31
# — Week 52 total: 0 articles
# [2025-04-20 15:37:36] Saved 1000 articles

# %%
import pandas as pd

# 1. Load both CSVs, parsing dates
other_df = pd.read_csv(
    'old_data.csv',
    parse_dates=['publish_date'],
    date_parser=lambda col: pd.to_datetime(col, utc=True)
)
gnews_df = pd.read_csv(
    'gnews_articles.csv',
    parse_dates=['publishedAt'],
    date_parser=lambda col: pd.to_datetime(col, utc=True)
)

# 2. Strip timezone info from both (make tz-naive)
other_df['publish_date'] = other_df['publish_date'].dt.tz_localize(None)
gnews_df['publishedAt']  = gnews_df['publishedAt'].dt.tz_localize(None)

# 3. Select & rename
other_trim = other_df[['publish_date', 'summary']].rename(
    columns={'publish_date': 'parsed_date', 'summary': 'Headline'}
)
gnews_trim = gnews_df[['publishedAt', 'title']].rename(
    columns={'publishedAt': 'parsed_date', 'title': 'Headline'}
)

# 4. Combine & sort
combined = pd.concat([other_trim, gnews_trim], ignore_index=True)
combined = combined.sort_values('parsed_date').reset_index(drop=True)

combined.to_csv('all_headlines.csv', index=False)

print(combined.head())
# Out:
#           parsed_date                                           Headline
# 0 2024-04-27 11:27:01  MMA News Roundup: Joe Rogan Gives His Verdict ...
# 1 2024-04-27 11:27:01  MMA News Roundup: Joe Rogan Gives His Verdict ...
# 2 2024-04-27 12:54:46  Exclusive: Apple's Upcoming Beats Solo Buds & ...
# 3 2024-04-27 12:54:46  Exclusive: Apple's Upcoming Beats Solo Buds & ...
# 4 2024-04-27 13:00:20  Match Group CEO Bernard Kim on romance scams: ...
# <ipython-input-12-b987fa3e6a10>:4: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   other_df = pd.read_csv(
# <ipython-input-12-b987fa3e6a10>:9: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   gnews_df = pd.read_csv(
